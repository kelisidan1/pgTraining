# %%
#test 看看好不好使
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(0,2*np.pi,0.01)
y=np.sin(x)

plt.plot(x,y)
plt.show()

y1=np.cos(x)
plt.plot(x,y1)
plt.show()

# %% [markdown]
# hello world!
